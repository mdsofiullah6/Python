# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("fiverr_victorioustudio.csv")

# Apply the value_counts method to the username column
counts = df['username'].value_counts()

# Convert the result of value_counts to a DataFrame
counts = counts.to_frame().reset_index()

# %%
counts
# Out:
#                index  username
# 0    williamchisholm        54
# 1          will_eyre        16
# 2      karlalopez715        15
# 3             bm1974        14
# 4          plusclub7        14
# ..               ...       ...
# 255  jonathanthom860         1
# 256      jmartinezaf         1
# 257        tinusbeer         1
# 258           neusid         1
# 259     thatsawkward         1
#
# [260 rows x 2 columns]

# %%
counts.to_csv('rank.csv')

# %%
# Rename the columns for clarity
counts.columns = ['username', 'count']

# Merge the counts DataFrame with the original DataFrame on the username column
result = counts.merge(df, on='username', how='left').drop_duplicates(subset='username')

# Rearrange the columns as desired
result = result[['username', 'country-name', 'count']]

# %%
result = result.reset_index(drop=True)

# %%
result.head(50)
# Out:
#            username    country-name  count
# 0   williamchisholm  United Kingdom     54
# 1         will_eyre  United Kingdom     16
# 2     karlalopez715   United States     15
# 3            bm1974   United States     14
# 4         plusclub7         Germany     14
# 5      jesusdiaz324          Mexico     14
# 6         masterken         Germany      9
# 7           tripsti         Estonia      8
# 8         jaymcbain   United States      7
# 9   otcshoppeexpres   United States      7
# 10  ryanlavender227   United States      7
# 11          emwiles   United States      7
# 12    juanjocallavi           Spain      7
# 13  pholisgunnellus   United States      7
# 14   musicfestivals   United States      6
# 15        kudosking   United States      6
# 16          ruglove  United Kingdom      6
# 17           nexnex       Singapore      6
# 18          nicodap          France      5
# 19       ahmedf1234          Norway      5
# 20           ejpczy   United States      5
# ...

# %%
result.to_csv('result.csv')
