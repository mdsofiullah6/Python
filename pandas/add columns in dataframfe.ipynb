# %%
import pandas as pd

# %%
electronics = {
    'name': ['car','crusher','computer','smartphone','laptop'],
    'price' : [3000,50000,3824,1000,4000]
}

# %%
fruit = {
    'name' : ['apple','banana','strewberry','mango','jackfrout'],
    'price' : ['34','59','37','23','53']
}

# %%
df = pd.DataFrame(fruit)

df
# Out:
#          name price
# 0       apple    34
# 1      banana    59
# 2  strewberry    37
# 3       mango    23
# 4   jackfrout    53

# %%
af = pd.DataFrame(electronics)
af
# Out:
#          name  price
# 0         car   3000
# 1     crusher  50000
# 2    computer   3824
# 3  smartphone   1000
# 4      laptop   4000

# %% [markdown]
# # Adding rows in data

# %%
df['a']= af['name']
df['p']= af['price']

# %%
df
# Out:
#          name price           a      p
# 0       apple    34         car   3000
# 1      banana    59     crusher  50000
# 2  strewberry    37    computer   3824
# 3       mango    23  smartphone   1000
# 4   jackfrout    53      laptop   4000

# %% [markdown]
# # Adding extra columns

# %%
import pandas as pd
# First DataFrame
df1 = pd.DataFrame({'id': ['A01', 'A02', '', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', '', 'DEF', 'GHI']})

  
# Second DataFrame
df2 = pd.DataFrame({'id': ['B05', 'B06', '','B07', 'B08'],
                    'Name': ['XYZ', 'TUV','', 'MNO', 'JKL']})
  
  
frames = [df1, df2]
  
result = pd.concat(frames)
result
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2
# 3  A03  DEF
# 4  A04  GHI
# 0  B05  XYZ
# 1  B06  TUV
# 2
# 3  B07  MNO
# 4  B08  JKL

# %%
df
# Out:
#          name price           a      p
# 0       apple    34         car   3000
# 1      banana    59     crusher  50000
# 2  strewberry    37    computer   3824
# 3       mango    23  smartphone   1000
# 4   jackfrout    53      laptop   4000

# %%
import pandas as pd
# First DataFrame
df1 = pd.read_csv("df.csv")

  
# Second DataFrame
df2 = pd.read_csv("df2.csv")
  
  
frames = [df1, df2]
  
result = pd.concat(frames)
result
# Out:
#      Unnamed: 0                                              LINK1  \
# 0             0  https://www.airbnb.com/rooms/show/747920750841...
# 1             1  https://www.airbnb.com/rooms/show/585581618267...
# 2             2         https://www.airbnb.com/rooms/show/19331356
# 3             3  https://www.airbnb.com/rooms/show/811554731268...
# 4             4  https://www.airbnb.com/rooms/show/729822793202...
# ..          ...                                                ...
# 198         198  https://www.airbnb.com/rooms/show/603760252237...
# 199         199  https://www.airbnb.com/rooms/show/786948801747...
# 200         200  https://www.airbnb.com/rooms/show/747815827335...
# 201         201         https://www.airbnb.com/rooms/show/52983694
# 202         202  https://www.airbnb.com/rooms/show/659541315632...
#
#                                            IMAGE_LINK1 PRICE1  \
# 0    https://a0.muscache.com/im/pictures/prohost-ap...  $334
# ...

# %%
result.to_csv('dahyun.csv')
