# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
people = {
    'name' : ['richard', 'dahyun' , 'nayeon' , 'sana',''],
    'title' : ['singularity','kim', '' , 'minatozaki',''],
    'country' : ['united state' , 'south korea' , 'south korea', 'japan' ,''],
    'food' : ['meat' , 'milk,chocklet milk' , 'salmon sushi','spicy food',''],
    'email' : ['richard@email.com' , 'dahyun@email.com' , 'nayeon@email.com', 'sana@email.com',''] ,
    'height_in_feet' : ['5.7' , '5.3' , '5.4', '5.4' ,''],
    'age' : ['18' , '24' , '27' ,'24','']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       name        title       country                food              email  \
# 0  richard  singularity  united state                meat  richard@email.com
# 1   dahyun          kim   south korea  milk,chocklet milk   dahyun@email.com
# 2   nayeon                south korea        salmon sushi   nayeon@email.com
# 3     sana   minatozaki         japan          spicy food     sana@email.com
# 4
#
#   height_in_feet age
# 0            5.7  18
# 1            5.3  24
# 2            5.4  27
# 3            5.4  24
# 4

# %% [markdown]
# # Adding columns

# %%
df['name']+' '+df['title']
# Out:
# 0    richard singularity
# 1             dahyun kim
# 2                nayeon
# 3        sana minatozaki
# 4
# dtype: object

# %%
df
# Out:
#       name        title       country                food              email  \
# 0  richard  singularity  united state                meat  richard@email.com
# 1   dahyun          kim   south korea  milk,chocklet milk   dahyun@email.com
# 2   nayeon                south korea        salmon sushi   nayeon@email.com
# 3     sana   minatozaki         japan          spicy food     sana@email.com
# 4
#
#   height_in_feet age
# 0            5.7  18
# 1            5.3  24
# 2            5.4  27
# 3            5.4  24
# 4

# %%
df['full_name'] = df['name']+' '+df['title']

# %%
df
# Out:
#       name        title       country                food              email  \
# 0  richard  singularity  united state                meat  richard@email.com
# 1   dahyun          kim   south korea  milk,chocklet milk   dahyun@email.com
# 2   nayeon                south korea        salmon sushi   nayeon@email.com
# 3     sana   minatozaki         japan          spicy food     sana@email.com
# 4
#
#   height_in_feet age            full_name
# 0            5.7  18  richard singularity
# 1            5.3  24           dahyun kim
# 2            5.4  27              nayeon
# 3            5.4  24      sana minatozaki
# 4

# %%
df.drop(['name'], axis=1 )
# Out:
#          title       country                food              email  \
# 0  singularity  united state                meat  richard@email.com
# 1          kim   south korea  milk,chocklet milk   dahyun@email.com
# 2                south korea        salmon sushi   nayeon@email.com
# 3   minatozaki         japan          spicy food     sana@email.com
# 4
#
#   height_in_feet age            full_name
# 0            5.7  18  richard singularity
# 1            5.3  24           dahyun kim
# 2            5.4  27              nayeon
# 3            5.4  24      sana minatozaki
# 4

# %%
df
# Out:
#       name        title       country                food              email  \
# 0  richard  singularity  united state                meat  richard@email.com
# 1   dahyun          kim   south korea  milk,chocklet milk   dahyun@email.com
# 2   nayeon                south korea        salmon sushi   nayeon@email.com
# 3     sana   minatozaki         japan          spicy food     sana@email.com
# 4
#
#   height_in_feet age            full_name
# 0            5.7  18  richard singularity
# 1            5.3  24           dahyun kim
# 2            5.4  27              nayeon
# 3            5.4  24      sana minatozaki
# 4

# %%
df.drop(columns=['name','title'],inplace=True)

# %%
df
# Out:
#         country                food              email height_in_feet age  \
# 0  united state                meat  richard@email.com            5.7  18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3  24
# 2   south korea        salmon sushi   nayeon@email.com            5.4  27
# 3         japan          spicy food     sana@email.com            5.4  24
# 4
#
#              full_name
# 0  richard singularity
# 1           dahyun kim
# 2              nayeon
# 3      sana minatozaki
# 4

# %%
df['full_name'].str.split(' ',expand=True)
# Out:
#          0            1
# 0  richard  singularity
# 1   dahyun          kim
# 2   nayeon
# 3     sana   minatozaki
# 4

# %%
df[['name','title']] = df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#         country                food              email height_in_feet age  \
# 0  united state                meat  richard@email.com            5.7  18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3  24
# 2   south korea        salmon sushi   nayeon@email.com            5.4  27
# 3         japan          spicy food     sana@email.com            5.4  24
# 4
#
#              full_name     name        title
# 0  richard singularity  richard  singularity
# 1           dahyun kim   dahyun          kim
# 2              nayeon    nayeon
# 3      sana minatozaki     sana   minatozaki
# 4

# %%
df.append({'name':'dube','title':'egale'},ignore_index = True)
# Out:
# C:\Users\Shofiullah\AppData\Local\Temp\ipykernel_4488\103863676.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'name':'dube','title':'egale'},ignore_index = True)
#         country                food              email height_in_feet  age  \
# 0  united state                meat  richard@email.com            5.7   18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3   24
# 2   south korea        salmon sushi   nayeon@email.com            5.4   27
# 3         japan          spicy food     sana@email.com            5.4   24
# 4
# 5           NaN                 NaN                NaN            NaN  NaN
#
#              full_name     name        title
# 0  richard singularity  richard  singularity
# 1           dahyun kim   dahyun          kim
# 2              nayeon    nayeon
# 3      sana minatozaki     sana   minatozaki
# 4
# 5                  NaN     dube        egale

# %%
people = {
    'name' : ['teayoung', 'jimin'],
    'title' : ['kim','park'],
    'country' : ['south korea' , 'south korea'],
    'food' : ['meat' , ' '],
    'email' : ['v@email.com' , 'jimin@email.com'] ,
    'height_in_feet' : ['5.7' , '5.3'],
    'age' : ['18' , '24' ]
}
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#        name title      country  food            email height_in_feet age
# 0  teayoung   kim  south korea  meat      v@email.com            5.7  18
# 1     jimin  park  south korea        jimin@email.com            5.3  24

# %% [markdown]
# # Append Dataframe

# %%
df.append(df1,ignore_index =True)
# Out:
# C:\Users\Shofiullah\AppData\Local\Temp\ipykernel_4488\4274805249.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df1,ignore_index =True)
#         country                food              email height_in_feet age  \
# 0  united state                meat  richard@email.com            5.7  18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3  24
# 2   south korea        salmon sushi   nayeon@email.com            5.4  27
# 3         japan          spicy food     sana@email.com            5.4  24
# 4
# 5   south korea                meat        v@email.com            5.7  18
# 6   south korea                        jimin@email.com            5.3  24
# 7   south korea                meat        v@email.com            5.7  18
# 8   south korea                        jimin@email.com            5.3  24
#
#              full_name      name        title
# 0  richard singularity   richard  singularity
# 1           dahyun kim    dahyun          kim
# 2              nayeon     nayeon
# 3      sana minatozaki      sana   minatozaki
# 4
# 5                  NaN  teayoung          kim
# 6                  NaN     jimin         park
# 7                  NaN  teayoung          kim
# 8                  NaN     jimin         park

# %%
df = df.append(df1,ignore_index =True)
# Out:
# C:\Users\Shofiullah\AppData\Local\Temp\ipykernel_4488\382732357.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1,ignore_index =True)

# %%
df
# Out:
#         country                food              email height_in_feet age  \
# 0  united state                meat  richard@email.com            5.7  18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3  24
# 2   south korea        salmon sushi   nayeon@email.com            5.4  27
# 3         japan          spicy food     sana@email.com            5.4  24
# 4
# 5   south korea                meat        v@email.com            5.7  18
# 6   south korea                        jimin@email.com            5.3  24
#
#              full_name      name        title
# 0  richard singularity   richard  singularity
# 1           dahyun kim    dahyun          kim
# 2              nayeon     nayeon
# 3      sana minatozaki      sana   minatozaki
# 4
# 5                  NaN  teayoung          kim
# 6                  NaN     jimin         park

# %% [markdown]
# # Removing index

# %%
df.drop(index=6)
# Out:
#         country                food              email height_in_feet age  \
# 0  united state                meat  richard@email.com            5.7  18
# 1   south korea  milk,chocklet milk   dahyun@email.com            5.3  24
# 2   south korea        salmon sushi   nayeon@email.com            5.4  27
# 3         japan          spicy food     sana@email.com            5.4  24
# 4
# 5   south korea                meat        v@email.com            5.7  18
#
#              full_name      name        title
# 0  richard singularity   richard  singularity
# 1           dahyun kim    dahyun          kim
# 2              nayeon     nayeon
# 3      sana minatozaki      sana   minatozaki
# 4
# 5                  NaN  teayoung          kim
